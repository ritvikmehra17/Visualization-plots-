# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

weather=pd.read_csv("Rainier_Weather.csv")

# %%
import plotly.express as px
fig=px.scatter(weather,x="Temperature AVG",y="Relative Humidity AVG",
              hover_name="Date",hover_data=["Battery Voltage AVG",
                                            "Solare Radiation AVG"])
fig.show()

# %%
import plotly.express as px
fig=px.scatter(weather,x="Temperature AVG",y="Relative Humidity AVG",
             )
fig.show()

# %%
import plotly.graph_objects as go


fig = go.Figure(go.Scatter(
    x=[1, 2, 3, 4, 5],
    y=[2.02825, 1.63728, 6.83839, 4.8485, 4.73463],
    hoverinfo="x,y",
    marker=dict(
        color="green"
    ),
    showlegend=False
))

fig.update_layout(
    title_text=("Set hover text formatting<br>" +
                "<a href= https://github.com/d3/d3-time-format/blob/master/README.md#locale_format>" +
                "https://github.com/d3/d3-time-format/blob/master/README.md#locale_format</a>"),
    title_font=dict(
        size=10
    ),
)

fig.update_xaxes(zeroline=False)
fig.update_yaxes(hoverformat=".2f")

fig.show()
