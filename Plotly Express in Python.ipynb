# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
weather=pd.read_csv("Rainier_Weather.csv")

# %%
weather.head()
# Out:
#          Date  Battery Voltage AVG  Temperature AVG  Relative Humidity AVG  \
# 0  12/31/2015            13.845000        19.062917              21.870833
# 1  12/30/2015            13.822917        14.631208              18.493833
# 2  12/29/2015            13.834583         6.614292              34.072917
# 3  12/28/2015            13.710417         8.687042              70.557917
# 4  12/27/2015            13.362500        14.140417              95.754167
#
#    Wind Speed Daily AVG  Wind Direction AVG  Solare Radiation AVG
# 0             21.977792           62.325833             84.915292
# 1              3.540542          121.505417             86.192833
# 2              0.000000          130.291667             85.100917
# 3              0.000000          164.683750             86.241250
# 4              0.000000          268.479167             31.090708

# %%
import plotly.express as px

# %% [markdown]
# fig=px.scatter(weather,x="Solare Radiation AVG",y="Temperature AVG",color="Date",
#               marginal_y="rug",marginal_x="histogram")
# fig.show()

# %% [markdown]
# import plotly.express as px
# fig=px.scatter(weather,x="Solare Radiation AVG",y="Temperature AVG",color="Date",
#               marginal_y="violin",marginal_x="box",trendline="ols")
# fig.show()

# %%
import plotly.express as px
fig=px.scatter_matrix(weather)
fig.show()

# %% [markdown]
# # Below graph is only for those color values which are yes or no ya male or female in a column of dataset

# %% [markdown]
# import plotly.express as px
# fog=px.scatter(weather,x="Solare Radiation AVG",y="Temperature AVG",color="Date",
#                facet_col="Date",color_continuous_scale=px.colors.sequential.Viridis,
#                render_mode="webgl")
# fig.show()

# %%
import plotly.express as px
fig=px.density_contour(weather,x="Solare Radiation AVG",y="Temperature AVG")
fig.show()

# %%
import plotly.express as px
fig=px.density_contour(weather,x="Solare Radiation AVG",y="Temperature AVG",
                      marginal_y="rug",marginal_x="histogram")
fig.show()

# %%
import plotly.express as px
fig=px.density_heatmap(weather,x="Solare Radiation AVG",y="Temperature AVG")
fig.show()

# %%
import plotly.express as px
fig=px.histogram(weather,x="Solare Radiation AVG",y="Temperature AVG",
                marginal="rug")
fig.show()

# %%
weather.head(1)
# Out:
#          Date  Battery Voltage AVG  Temperature AVG  Relative Humidity AVG  \
# 0  12/31/2015               13.845        19.062917              21.870833
#
#    Wind Speed Daily AVG  Wind Direction AVG  Solare Radiation AVG
# 0             21.977792           62.325833             84.915292

# %% [markdown]
# import plotly.express as px
# fig=px.line_polar(weather,r="Wind Speed Daily AVG",theta="Wind Speed Daily AVG",color="Temperature AVG", template="plotly_dark",
#             color_discrete_sequence= px.colors.sequential.Plasma[-2::-1])
# fig.show()
